# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train = pd.read_excel('Train_dataset.xlsx')

# %%
train.head()
# Out:
#    people_ID        Region  Gender Designation             Name Married  \
# 0          1  Bhubaneshwar  Female         Mrs            mansi     YES
# 1          2  Bhubaneshwar  Female         Mrs        riya masi     YES
# 2          3  Bhubaneshwar  Female         Mrs           sunita      NO
# 3          4  Bhubaneshwar  Female         Mrs   anjali @ babli     YES
# 4          5  Bhubaneshwar  Female         Mrs  champa karketta      NO
#
#    Children     Occupation Mode_transport  cases/1M  ...    HBB d-dimer  \
# 0       1.0         Farmer         Public         2  ...   93.0   233.0
# 1       2.0         Farmer           Walk         2  ...   56.0   328.0
# 2       1.0        Cleaner         Public         2  ...  137.0   213.0
# 3       1.0         Driver            Car         2  ...  167.0   275.0
# 4       2.0  Manufacturing            Car         2  ...  153.0   331.0
#
#    Heart rate  HDL cholesterol Charlson Index Blood Glucose  Insurance  \
# ...

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 28 columns):
# people_ID                 10714 non-null int64
# Region                    10714 non-null object
# Gender                    10714 non-null object
# Designation               10714 non-null object
# Name                      10694 non-null object
# Married                   10714 non-null object
# Children                  10403 non-null float64
# Occupation                9967 non-null object
# Mode_transport            10711 non-null object
# cases/1M                  10714 non-null int64
# Deaths/1M                 10714 non-null int64
# comorbidity               10488 non-null object
# Age                       10714 non-null int64
# Coma score                10714 non-null int64
# Pulmonary score           10714 non-null object
# cardiological pressure    10617 non-null object
# Diuresis                  9998 non-null float64
# ...

# %%
train.drop('Designation',axis=1,inplace=True)

# %%
train.drop('Name',axis=1,inplace=True)

# %%
train.head()
# Out:
#    people_ID        Region  Gender Married  Children     Occupation  \
# 0          1  Bhubaneshwar  Female     YES       1.0         Farmer
# 1          2  Bhubaneshwar  Female     YES       2.0         Farmer
# 2          3  Bhubaneshwar  Female      NO       1.0        Cleaner
# 3          4  Bhubaneshwar  Female     YES       1.0         Driver
# 4          5  Bhubaneshwar  Female      NO       2.0  Manufacturing
#
#   Mode_transport  cases/1M  Deaths/1M             comorbidity  ...    HBB  \
# 0         Public         2          0            Hypertension  ...   93.0
# 1           Walk         2          0                Diabetes  ...   56.0
# 2         Public         2          0                    None  ...  137.0
# 3            Car         2          0  Coronary Heart Disease  ...  167.0
# 4            Car         2          0                Diabetes  ...  153.0
#
#    d-dimer Heart rate HDL cholesterol  Charlson Index  Blood Glucose  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 26 columns):
# people_ID                 10714 non-null int64
# Region                    10714 non-null object
# Gender                    10714 non-null object
# Married                   10714 non-null object
# Children                  10403 non-null float64
# Occupation                9967 non-null object
# Mode_transport            10711 non-null object
# cases/1M                  10714 non-null int64
# Deaths/1M                 10714 non-null int64
# comorbidity               10488 non-null object
# Age                       10714 non-null int64
# Coma score                10714 non-null int64
# Pulmonary score           10714 non-null object
# cardiological pressure    10617 non-null object
# Diuresis                  9998 non-null float64
# Platelets                 9790 non-null float64
# HBB                       10698 non-null float64
# ...

# %%
sns.distplot([train['Infect_Prob']])

# %%
sns.heatmap(train.corr())

# %%
train["Children"].fillna('0', inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 26 columns):
# people_ID                 10714 non-null int64
# Region                    10714 non-null object
# Gender                    10714 non-null object
# Married                   10714 non-null object
# Children                  10714 non-null object
# Occupation                9967 non-null object
# Mode_transport            10711 non-null object
# cases/1M                  10714 non-null int64
# Deaths/1M                 10714 non-null int64
# comorbidity               10488 non-null object
# Age                       10714 non-null int64
# Coma score                10714 non-null int64
# Pulmonary score           10714 non-null object
# cardiological pressure    10617 non-null object
# Diuresis                  9998 non-null float64
# Platelets                 9790 non-null float64
# HBB                       10698 non-null float64
# ...

# %%
train['Children'].isnull().sum()
# Out:
# 0

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train['Occupation'].isnull().sum()
# Out:
# 747

# %%
train.drop('Occupation',axis=1,inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 25 columns):
# people_ID                 10714 non-null int64
# Region                    10714 non-null object
# Gender                    10714 non-null object
# Married                   10714 non-null object
# Children                  10714 non-null object
# Mode_transport            10711 non-null object
# cases/1M                  10714 non-null int64
# Deaths/1M                 10714 non-null int64
# comorbidity               10488 non-null object
# Age                       10714 non-null int64
# Coma score                10714 non-null int64
# Pulmonary score           10714 non-null object
# cardiological pressure    10617 non-null object
# Diuresis                  9998 non-null float64
# Platelets                 9790 non-null float64
# HBB                       10698 non-null float64
# d-dimer                   9600 non-null float64
# ...

# %%
train['comorbidity'].isnull().sum()
# Out:
# 226

# %%
train["comorbidity"].fillna('None', inplace = True)

# %%
train['comorbidity'].isnull().sum()
# Out:
# 0

# %%
train['cardiological pressure'].isnull().sum()
# Out:
# 97

# %%
train["cardiological pressure"].fillna('Normal', inplace = True)

# %%
train.describe()
# Out:
#           people_ID      cases/1M     Deaths/1M           Age    Coma score  \
# count  10714.000000  10714.000000  10714.000000  10714.000000  10714.000000
# mean   10084.893784      3.285888      0.523241     42.083722      9.013067
# std     7108.663645      2.721274      0.854303     15.323397      3.714970
# min        1.000000      1.000000      0.000000     16.000000      3.000000
# 25%     2679.250000      2.000000      0.000000     29.000000      6.000000
# 50%    10003.500000      2.000000      0.000000     42.000000      9.000000
# 75%    15141.750000      4.000000      1.000000     55.000000     12.000000
# max    22695.000000      8.000000      2.000000     68.000000     15.000000
#
#           Diuresis    Platelets           HBB      d-dimer   Heart rate  \
# count  9998.000000  9790.000000  10698.000000  9600.000000  9600.000000
# mean    278.806261    87.795812    116.170967   275.292292    74.847396
# ...

# %%
train["Diuresis"].fillna('280', inplace = True)

# %%
train.describe()
# Out:
#           people_ID      cases/1M     Deaths/1M           Age    Coma score  \
# count  10714.000000  10714.000000  10714.000000  10714.000000  10714.000000
# mean   10084.893784      3.285888      0.523241     42.083722      9.013067
# std     7108.663645      2.721274      0.854303     15.323397      3.714970
# min        1.000000      1.000000      0.000000     16.000000      3.000000
# 25%     2679.250000      2.000000      0.000000     29.000000      6.000000
# 50%    10003.500000      2.000000      0.000000     42.000000      9.000000
# 75%    15141.750000      4.000000      1.000000     55.000000     12.000000
# max    22695.000000      8.000000      2.000000     68.000000     15.000000
#
#          Platelets           HBB      d-dimer   Heart rate  HDL cholesterol  \
# count  9790.000000  10698.000000  9600.000000  9600.000000     10679.000000
# mean     87.795812    116.170967   275.292292    74.847396        52.632737
# ...

# %%
train.head()
# Out:
#    people_ID        Region  Gender Married Children Mode_transport  cases/1M  \
# 0          1  Bhubaneshwar  Female     YES        1         Public         2
# 1          2  Bhubaneshwar  Female     YES        2           Walk         2
# 2          3  Bhubaneshwar  Female      NO        1         Public         2
# 3          4  Bhubaneshwar  Female     YES        1            Car         2
# 4          5  Bhubaneshwar  Female      NO        2            Car         2
#
#    Deaths/1M             comorbidity  Age  ...    HBB d-dimer Heart rate  \
# 0          0            Hypertension   68  ...   93.0   233.0       82.0
# 1          0                Diabetes   64  ...   56.0   328.0       89.0
# 2          0                    None   19  ...  137.0   213.0       77.0
# 3          0  Coronary Heart Disease   33  ...  167.0   275.0       64.0
# 4          0                Diabetes   23  ...  153.0   331.0       71.0
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 25 columns):
# people_ID                 10714 non-null int64
# Region                    10714 non-null object
# Gender                    10714 non-null object
# Married                   10714 non-null object
# Children                  10714 non-null object
# Mode_transport            10711 non-null object
# cases/1M                  10714 non-null int64
# Deaths/1M                 10714 non-null int64
# comorbidity               10714 non-null object
# Age                       10714 non-null int64
# Coma score                10714 non-null int64
# Pulmonary score           10714 non-null object
# cardiological pressure    10714 non-null object
# Diuresis                  10714 non-null object
# Platelets                 9790 non-null float64
# HBB                       10698 non-null float64
# d-dimer                   9600 non-null float64
# ...

# %%
train["Platelets"].fillna('88', inplace = True)

# %%
train["HBB"].fillna('116', inplace = True)

# %%
train["d-dimer"].fillna('275', inplace = True)

# %%
train["Heart rate"].fillna('75', inplace = True)

# %%
train["HDL cholesterol"].fillna('53', inplace = True)

# %%
train["Insurance"].fillna('2644919', inplace = True)

# %%
train["FT/month"].fillna('1', inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 25 columns):
# people_ID                 10714 non-null int64
# Region                    10714 non-null object
# Gender                    10714 non-null object
# Married                   10714 non-null object
# Children                  10714 non-null object
# Mode_transport            10711 non-null object
# cases/1M                  10714 non-null int64
# Deaths/1M                 10714 non-null int64
# comorbidity               10714 non-null object
# Age                       10714 non-null int64
# Coma score                10714 non-null int64
# Pulmonary score           10714 non-null object
# cardiological pressure    10714 non-null object
# Diuresis                  10714 non-null object
# Platelets                 10714 non-null object
# HBB                       10714 non-null object
# d-dimer                   10714 non-null object
# ...

# %%
train.describe()
# Out:
#           people_ID      cases/1M     Deaths/1M           Age    Coma score  \
# count  10714.000000  10714.000000  10714.000000  10714.000000  10714.000000
# mean   10084.893784      3.285888      0.523241     42.083722      9.013067
# std     7108.663645      2.721274      0.854303     15.323397      3.714970
# min        1.000000      1.000000      0.000000     16.000000      3.000000
# 25%     2679.250000      2.000000      0.000000     29.000000      6.000000
# 50%    10003.500000      2.000000      0.000000     42.000000      9.000000
# 75%    15141.750000      4.000000      1.000000     55.000000     12.000000
# max    22695.000000      8.000000      2.000000     68.000000     15.000000
#
#        Charlson Index  Blood Glucose        salary   Infect_Prob
# count    10714.000000   10714.000000  1.071400e+04  10714.000000
# mean        20.028094       5.015027  1.304713e+06     52.280680
# std         11.828445       1.399770  6.075947e+05     10.674667
# ...

# %%
train.head()
# Out:
#    people_ID        Region  Gender Married Children Mode_transport  cases/1M  \
# 0          1  Bhubaneshwar  Female     YES        1         Public         2
# 1          2  Bhubaneshwar  Female     YES        2           Walk         2
# 2          3  Bhubaneshwar  Female      NO        1         Public         2
# 3          4  Bhubaneshwar  Female     YES        1            Car         2
# 4          5  Bhubaneshwar  Female      NO        2            Car         2
#
#    Deaths/1M             comorbidity  Age  ...  HBB d-dimer Heart rate  \
# 0          0            Hypertension   68  ...   93     233         82
# 1          0                Diabetes   64  ...   56     328         89
# 2          0                    None   19  ...  137     213         77
# 3          0  Coronary Heart Disease   33  ...  167     275         64
# 4          0                Diabetes   23  ...  153     331         71
#
# ...

# %%
sex = pd.get_dummies(train['Gender'],drop_first=True)

# %%
Location = pd.get_dummies(train['Region'],drop_first=True)

# %%
Marry = pd.get_dummies(train['Married'],drop_first=True)

# %%
Transport = pd.get_dummies(train['Mode_transport'],drop_first=True)

# %%
Comor = pd.get_dummies(train['comorbidity'],drop_first=True)

# %%
Pressure = pd.get_dummies(train['cardiological pressure'],drop_first=True)

# %%
train = pd.concat([train,sex,Location,Marry,Transport,Comor,Pressure],axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 39 columns):
# people_ID                 10714 non-null int64
# Region                    10714 non-null object
# Gender                    10714 non-null object
# Married                   10714 non-null object
# Children                  10714 non-null object
# Mode_transport            10711 non-null object
# cases/1M                  10714 non-null int64
# Deaths/1M                 10714 non-null int64
# comorbidity               10714 non-null object
# Age                       10714 non-null int64
# Coma score                10714 non-null int64
# Pulmonary score           10714 non-null object
# cardiological pressure    10714 non-null object
# Diuresis                  10714 non-null object
# Platelets                 10714 non-null object
# HBB                       10714 non-null object
# d-dimer                   10714 non-null object
# ...

# %%
X = train.drop('Infect_Prob',axis=1)
X.head()
# Out:
#    people_ID        Region  Gender Married Children Mode_transport  cases/1M  \
# 0          1  Bhubaneshwar  Female     YES        1         Public         2
# 1          2  Bhubaneshwar  Female     YES        2           Walk         2
# 2          3  Bhubaneshwar  Female      NO        1         Public         2
# 3          4  Bhubaneshwar  Female     YES        1            Car         2
# 4          5  Bhubaneshwar  Female      NO        2            Car         2
#
#    Deaths/1M             comorbidity  Age  ...  Delhi YES Public Walk  \
# 0          0            Hypertension   68  ...      0   1      1    0
# 1          0                Diabetes   64  ...      0   1      0    1
# 2          0                    None   19  ...      0   0      1    0
# 3          0  Coronary Heart Disease   33  ...      0   1      0    0
# 4          0                Diabetes   23  ...      0   0      0    0
#
#   Diabetes Hypertension None Normal Stage-01  Stage-02
# ...

# %%
train.drop('Region',axis=1,inplace=True)

# %%
train.drop('Gender',axis=1,inplace=True)

# %%
train.drop('Mode_transport',axis=1,inplace=True)

# %%
train.drop('Married',axis=1,inplace=True)

# %%
train.drop('comorbidity',axis=1,inplace=True)

# %%
train.drop('cardiological pressure',axis=1,inplace=True)

# %%
y = train['Infect_Prob']
y.head()
# Out:
# 0    49.135010
# 1    51.147880
# 2    73.224000
# 3    48.779225
# 4    87.868800
# Name: Infect_Prob, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
train['Pulmonary score'] = train['Pulmonary score'].map(lambda x: x.lstrip('<').rstrip('aAbBcC'))

# %%
X = train.drop('Infect_Prob',axis=1)
X.head()
# Out:
#    people_ID Children  cases/1M  Deaths/1M  Age  Coma score Pulmonary score  \
# 0          1        1         2          0   68           8             400
# 1          2        2         2          0   64          15             100
# 2          3        1         2          0   19          13             300
# 3          4        1         2          0   33           9             200
# 4          5        2         2          0   23           7             400
#
#   Diuresis Platelets  HBB  ... Delhi YES Public  Walk  Diabetes Hypertension  \
# 0      441       154   93  ...     0   1      1     0         0            1
# 1      280       121   56  ...     0   1      0     1         1            0
# 2      416       124  137  ...     0   0      1     0         0            0
# 3      410        98  167  ...     0   1      0     0         0            0
# 4      390        21  153  ...     0   0      0     0         1            0
#
#    None Normal  Stage-01  Stage-02
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 33 columns):
# people_ID          10714 non-null int64
# Children           10714 non-null object
# cases/1M           10714 non-null int64
# Deaths/1M          10714 non-null int64
# Age                10714 non-null int64
# Coma score         10714 non-null int64
# Pulmonary score    10714 non-null object
# Diuresis           10714 non-null object
# Platelets          10714 non-null object
# HBB                10714 non-null object
# d-dimer            10714 non-null object
# Heart rate         10714 non-null object
# HDL cholesterol    10714 non-null object
# Charlson Index     10714 non-null int64
# Blood Glucose      10714 non-null int64
# Insurance          10714 non-null object
# salary             10714 non-null int64
# FT/month           10714 non-null object
# Infect_Prob        10714 non-null float64
# Male               10714 non-null uint8
# ...

# %%
logmodel = LinearRegression()
logmodel.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(logmodel.intercept_)
# Out:
# 55.19548380425769

# %%
coeff_df = pd.DataFrame(logmodel.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                   Coefficient
# people_ID        7.662306e-05
# Children         2.066024e+00
# cases/1M         6.151167e-01
# Deaths/1M        5.761934e-02
# Age             -1.248795e-02
# Coma score       9.540506e-02
# Pulmonary score -2.997361e-03
# Diuresis        -2.652545e-04
# Platelets        1.711652e-02
# HBB              3.904991e-03
# d-dimer          2.154087e-03
# Heart rate       3.080017e-04
# HDL cholesterol  2.497172e-02
# Charlson Index  -1.870937e-03
# Blood Glucose   -8.496196e-02
# Insurance       -5.973798e-09
# salary          -3.742792e-07
# FT/month        -1.156864e-02
# Male            -1.192394e+00
# Bhubaneshwar    -4.808953e-02
# Chandigarh       1.633253e-02
# Chennai          4.481533e-01
# Delhi           -8.904120e-01
# YES             -1.220762e+01
# Public           3.644727e-01
# Walk             1.473490e-01
# Diabetes        -3.546449e-01
# Hypertension    -1.160372e-01
# None            -2.375620e-01
# Normal           3.643353e-01
# ...

# %%
predictions = logmodel.predict(X_test)

# %%
print(predictions)
# Out:
# [51.42805909 48.79878755 47.56145721 ... 62.73610765 52.00775842
#  50.12710734]

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# calculate these metrics by hand!
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 4.442871433983277
# MSE: 79.94944091060631
# RMSE: 8.941445124285353

# %%
sns.distplot((y_test-predictions),bins=50);

# %%
test = pd.read_csv('New_Test.csv')

# %%
test.head()
# Out:
#    people_ID  Children  cases/1M  Deaths/1M  Age  Coma score  Pulmonary score  \
# 0       5942         2         4          1   52           3              200
# 1      18664         2         4          1   53          11              200
# 2       5603         2         4          1   35           9              100
# 3       5649         2         4          1   31          12              300
# 4       5099         2         4          1   51           6              200
#
#    Diuresis  Platelets  HBB  ...  Pune  YES  Public  Walk  Diabetes  \
# 0       388        153  196  ...     0    1       1     0         1
# 1       409         95  138  ...     0    1       0     1         1
# 2       440         40  166  ...     0    1       0     0         1
# 3       206         78   83  ...     0    1       0     0         0
# 4       229        109  207  ...     0    1       0     0         1
#
#    Hypertension  None  Normal  Stage-01  Stage-02
# ...

# %%
New_predictions = logmodel.predict(test)

# %%
New_predictions
# Out:
# array([53.04576899, 52.20836491, 51.49245801, ..., 51.20353425,
#        50.9711443 , 51.55749819])

# %%
New_predictions = pd.DataFrame(New_predictions)

# %%
New_predictions
# Out:
#                0
# 0      53.045769
# 1      52.208365
# 2      51.492458
# 3      52.275885
# 4      52.503469
# ...          ...
# 14493  51.125774
# 14494  50.132960
# 14495  51.203534
# 14496  50.971144
# 14497  51.557498
#
# [14498 rows x 1 columns]

# %%
test = pd.concat([test,New_predictions],axis=1)

# %%
test.head()
# Out:
#    people_ID  Children  cases/1M  Deaths/1M  Age  Coma score  Pulmonary score  \
# 0       5942         2         4          1   52           3              200
# 1      18664         2         4          1   53          11              200
# 2       5603         2         4          1   35           9              100
# 3       5649         2         4          1   31          12              300
# 4       5099         2         4          1   51           6              200
#
#    Diuresis  Platelets  HBB  ...  YES  Public  Walk  Diabetes  Hypertension  \
# 0       388        153  196  ...    1       1     0         1             0
# 1       409         95  138  ...    1       0     1         1             0
# 2       440         40  166  ...    1       0     0         1             0
# 3       206         78   83  ...    1       0     0         0             0
# 4       229        109  207  ...    1       0     0         1             0
#
# ...

# %%
test.columns
# Out:
# Index([      'people_ID',        'Children',        'cases/1M',
#              'Deaths/1M',             'Age',      'Coma score',
#        'Pulmonary score',        'Diuresis',       'Platelets',
#                    'HBB',         'd-dimer',      'Heart rate',
#        'HDL cholesterol',  'Charlson Index',   'Blood Glucose',
#              'Insurance',          'salary',        'FT/month',
#                   'Male',       'Hyderabad',         'Kolkata',
#                 'Mumbai',            'Pune',             'YES',
#                 'Public',            'Walk',        'Diabetes',
#           'Hypertension',            'None',          'Normal',
#               'Stage-01',        'Stage-02',                 0],
#       dtype='object')

# %%
test.drop([        'Children',        'cases/1M',
             'Deaths/1M',             'Age',      'Coma score',
       'Pulmonary score',        'Diuresis',       'Platelets',
                   'HBB',         'd-dimer',      'Heart rate',
       'HDL cholesterol',  'Charlson Index',   'Blood Glucose',
             'Insurance',          'salary',        'FT/month',
                  'Male',       'Hyderabad',         'Kolkata',
                'Mumbai',            'Pune',             'YES',
                'Public',            'Walk',        'Diabetes',
          'Hypertension',            'None',          'Normal',
              'Stage-01',        'Stage-02'],axis=1,inplace=True)

# %%
test.head()
# Out:
#    people_ID          0
# 0       5942  53.045769
# 1      18664  52.208365
# 2       5603  51.492458
# 3       5649  52.275885
# 4       5099  52.503469

# %%
test.to_csv('Predicted.csv',index=False)
